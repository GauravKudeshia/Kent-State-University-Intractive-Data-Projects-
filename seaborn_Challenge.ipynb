# %% [markdown]
# ### Group 1:
#
# **Q1, Open a new Jupyter Notebook and import the pandas, matplotlib, and seaborn libraries in the same cell. Set the theme to "dark grid".**

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %% [markdown]
# **Q2, Import the "Diabetes.csv Download Diabetes.csv" file and convert it to a DataFrame object using the pandas.read_csv() method.**

# %%
diabetes = pd.read_csv('Diabetes (1).csv')
diabetes
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0              2  115.863387      56.410731      24.336736   94.385783
# 1              2   92.490122      70.615520      23.443591  138.652426
# 2              1   88.141469      63.262618      23.404364  149.358082
# 3              2  108.453101      67.793632      20.751580  108.751638
# 4              1  127.849443      94.725685      22.603078   25.269987
# ..           ...         ...            ...            ...         ...
# 995            1  103.496355      41.059401      24.930299   43.675978
# 996            1   60.714150      64.082842      24.689064  111.562745
# 997            0   97.597727      64.122312      22.140339  108.138552
# 998            0   66.775137      55.908797      24.885274  219.521484
# 999            0   87.647268      69.111593      25.621266  134.335745
#
#            BMI  DiabetesPedigreeFunction        Age  Diagnosis
# ...

# %% [markdown]
# **Q3, Create a scatter plot figure using the relplot function, with "Age" as the x-axis variable and "Insulin" as the y-axis variable.**

# %%
sns.scatterplot(x=diabetes['BMI'], y = diabetes['Glucose'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Q4, In a new cell, create the same scatter plot figure, but this time add "Pregnancies" as the variable for "hue" and "size"**

# %%
sns.relplot(data=diabetes, x="BMI", y="Glucose", hue = "Pregnancies")

# %%
sns.relplot(data=diabetes, x="BMI", y="Glucose", size = "Pregnancies")

# %%
sns.relplot(data=diabetes, x="BMI", y="Glucose", hue = "Pregnancies",sizes = (10,50))

# %% [markdown]
# **Q5, Finally, use the plt.xlim() and plt.ylim() methods to set limits for the x and y axes, and zoom in on your data**

# %%
sns.relplot(data=diabetes, x="BMI", y="Glucose", hue = "Pregnancies",sizes = (10,50))
plt.xlim(18, 37)
plt.ylim(50, 140)
plt.show()

# %%
sns.relplot(data=diabetes, x="BMI", y="Glucose", hue = "Pregnancies",size = "Pregnancies", sizes = (10,50))
plt.xlim(18, 37)
plt.ylim(50, 140)
plt.show()

# %% [markdown]
# ### Challenge Group - 1

# %% [markdown]
# **Creating Scatter Plot with "Age" & "Insulin"**

# %%
sns.relplot(data = diabetes, x="Age", y="Insulin")
plt.show()

# %%
sns.relplot(data=diabetes, x='Age', y = 'Insulin', hue = 'Pregnancies',size = 'Pregnancies')
plt.xlim(15, 65)
plt.ylim(-50, 200)
plt.show()

# %% [markdown]
# **Q6, In a Markdown cell, explain how a different method of relplot can be used to help improve understanding of the variable relationships in your figure.**
#
# Ans: Seaborn's relplot to visualize relationships between 'Age' and 'Insulin' levels, colored and sized by 'Pregnancies'. This method enhances understanding by showing how pregnancy count impacts insulin levels across different ages. Different colors and sizes for 'Pregnancies' allow for easy comparison, highlighting patterns or trends among these variables. Adjusting x and y limits focuses the analysis on specific age and insulin ranges, making the figure clearer and more informative by removing outliers or irrelevant data points. This approach will helps in identifying how pregnancy affects insulin requirements with age.

# %% [markdown]
# ### Group 2

# %% [markdown]
# **Import the "Salary Data.csv Download Salary Data.csv" file, which can also be accessed through the following link Salary_dataset (this data already follows tidy data principles).**

# %%
sns.set(style="whitegrid")

# %%
salary_data = pd.read_csv('Salary Data.csv')
salary_data
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
salary_data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %% [markdown]
# **Q1, Initial Exploration:
# Create a scatter plot using Seaborn default settings with Age on the x-axis and Salary on the y-axis.**

# %%
plt.figure()
sns.scatterplot(x = 'Age', y = 'Salary', data = salary_data)
plt.title('Default Scatter Plot: Ave vs Salary')
plt.show()

# %% [markdown]
# **Q2, Visualization:**
#
# - Explore the dataset and seaborn package by creating an advanced scatter plot.
# - Include Gender and Education Level as attributes in the legend.
# - Customize the color and marker palettes to increase visual appeal.

# %%
plt.figure()
sns.scatterplot(x = 'Age',\
               y = 'Salary',\
               hue= 'Education Level',\
               style = 'Gender',\
               data = salary_data)
plt.title('Scatter Plot: Ave vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

# Creating a scatter plot Age vs salary and adding additional information for the education level and gender
plt.figure()
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=salary_data, palette=education_colors)
plt.title('Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %% [markdown]
# **Q3, Styling and Customization:**
#
# - Set the plot style to remove grid lines for a cleaner look.
# - Customize the legend to provide clear information without distracting from the plot.

# %%
#Defining custom color palette
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

#Defining custom color palette
gender_makers={"Female":"o","Male":"s"}
# Creating a scatter plot Age vs salary and adding additional information for the education level and gender
plt.figure()
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=salary_data, palette=education_colors, markers=gender_makers)
plt.title('Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
#Defining custom color palette
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

#Defining custom color palette
gender_makers={"Female":"o","Male":"s"}

plt.figure(figsize=(12,8))
sns.set_style("ticks")
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=salary_data, palette=education_colors, markers=gender_makers)
plt.title('Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}
gender_makers={"Female":"o","Male":"s"}
plt.figure(figsize=(12,8))
sns.set_style("ticks")
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=salary_data, palette=education_colors, markers=gender_makers)

#removing legend frame and dividing it in 2 columns
plt.legend(ncol=2, frameon=False, loc="lower right")
plt.title('Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %% [markdown]
# **Q4, Additional Analysis :**
#
# - As the final scatter plot is too cluttered, create separate plots for each education level utilizing the filtered data frame option and setting the x and y axes limits.
# - Explore other Seaborn plot types (e.g., bar plots, box plots) to extract more insights from the dataset.

# %%
gender_colors = {"Female": "red", "Male": "blue"}

plt.figure(figsize=(10, 8))
sns.set_style("ticks")  # no gridlines

Bachelors = sns.scatterplot(x="Age", y="Salary", hue="Gender", style="Gender",
                            data=salary_data[salary_data["Education Level"] == "Bachelor's"],
                            palette=gender_colors)

# Setting limits for x and y axes
Bachelors.set_xlim(25, 50)
Bachelors.set_ylim(50000, 250000)

# Customizing the legend
plt.legend(frameon=False, loc="upper left")

plt.title("Age vs Salary Based on Gender Among Bachelor's Degree Holders")
plt.show()

# %%
gender_colors = {"Female": "red", "Male": "blue"}

plt.figure(figsize=(10, 8))
sns.set_style("ticks")  # no gridlines

Bachelors = sns.scatterplot(x="Age", y="Salary", hue="Gender", style="Gender",
                            data=salary_data[salary_data["Education Level"] == "Master's"],
                            palette=gender_colors)

# Setting limits for x and y axes
Bachelors.set_xlim(25, 50)
Bachelors.set_ylim(50000, 250000)

# Customizing the legend
plt.legend(frameon=False, loc="upper left")

plt.title("Age vs Salary Based on Gender Among Master's Degree Holders")
plt.show()

# %%
gender_colors = {"Female": "red", "Male": "blue"}

plt.figure(figsize=(10, 8))
sns.set_style("ticks")  # no gridlines

Bachelors = sns.scatterplot(x="Age", y="Salary", hue="Gender", style="Gender",
                            data=salary_data[salary_data["Education Level"] == "PhD"],
                            palette=gender_colors)

# Setting limits for x and y axes
Bachelors.set_xlim(25, 50)
Bachelors.set_ylim(50000, 250000)

# Customizing the legend
plt.legend(frameon=False, loc="upper left")

plt.title("Age vs Salary Based on Gender Among PhD's Degree Holders")
plt.show()

# %% [markdown]
# ### Creating bar charts in seaborn

# %%
#Creating a bar chart
sns.barplot(x='Years of Experience', y = 'Education Level', hue = 'Gender', data=salary_data)
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Education Level'>

# %%
sns.boxplot(x='Years of Experience', y='Education Level', hue='Gender', data = salary_data)
plt.show()

# %%
# Added cap on bar 
sns.barplot(y='Years of Experience',x='Education Level',hue='Gender',capsize=0.2,data=salary_data)
# Out:
# <Axes: xlabel='Education Level', ylabel='Years of Experience'>

# %%
#Creating a bar chart with capsize and palette will be dark & blue.
sns.barplot(x='Years of Experience', y = 'Education Level', hue = 'Gender',capsize=0.2, data=salary_data, errorbar=None, palette='dark:blue',hue_order=['Female','Male'])
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Education Level'>
